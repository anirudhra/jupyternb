# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install scipy
# !{sys.executable} -m pip install pandas scikit-learn
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install xlrd
# !{sys.executable} -m pip install scrapy
# !{sys.executable} -m pip install mitoinstaller
# !{sys.executable} -m pip install pandas-profiling
# !{sys.executable} -m pip install lux-api
# !{sys.executable} -m pip install plotly
# !{sys.executable} -m pip install bokeh
# !{sys.executable} -m pip install mahotas
# !{sys.executable} -m pip install simpleitk
# !{sys.executable} -m pip install selenium
# !{sys.executable} -m pip install beautifulsoup4
# !{sys.executable} -m pip install yahoo-finance
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/site-packages (23.0.1)
# Collecting pip
#   Using cached pip-23.1.2-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# Successfully installed pip-23.1.2
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (1.24.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.11/site-packages (from scipy) (1.24.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.11/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: scrapy in /usr/local/lib/python3.11/site-packages (2.9.0)
# Requirement already satisfied: Twisted>=18.9.0 in /usr/local/lib/python3.11/site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=3.4.6 in /usr/local/lib/python3.11/site-packages (from scrapy) (41.0.1)
# Requirement already satisfied: cssselect>=0.9.1 in /usr/local/lib/python3.11/site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /usr/local/lib/python3.11/site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in /usr/local/lib/python3.11/site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /usr/local/lib/python3.11/site-packages (from scrapy) (23.2.0)
# Requirement already satisfied: queuelib>=1.4.2 in /usr/local/lib/python3.11/site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in /usr/local/lib/python3.11/site-packages (from scrapy) (23.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in /usr/local/lib/python3.11/site-packages (from scrapy) (2.1.1)
# Requirement already satisfied: zope.interface>=5.1.0 in /usr/local/lib/python3.11/site-packages (from scrapy) (6.0)
# Requirement already satisfied: protego>=0.1.15 in /usr/local/lib/python3.11/site-packages (from scrapy) (0.2.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /usr/local/lib/python3.11/site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/site-packages (from scrapy) (67.6.1)
# Requirement already satisfied: packaging in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from scrapy) (23.0)
# Requirement already satisfied: tldextract in /usr/local/lib/python3.11/site-packages (from scrapy) (3.4.4)
# Requirement already satisfied: lxml>=4.3.0 in /usr/local/lib/python3.11/site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /usr/local/lib/python3.11/site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/site-packages (from cryptography>=3.4.6->scrapy) (1.15.1)
# Requirement already satisfied: jmespath>=0.9.5 in /usr/local/lib/python3.11/site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/site-packages (from protego>=0.1.15->scrapy) (1.16.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (0.5.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in /usr/local/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: Automat>=0.8.0 in /usr/local/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy) (4.7.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/site-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.11/site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.11/site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/site-packages (from tldextract->scrapy) (3.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.1.0->tldextract->scrapy) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.1.0->tldextract->scrapy) (2023.5.7)
# Requirement already satisfied: mitoinstaller in /usr/local/lib/python3.11/site-packages (0.0.224)
# Requirement already satisfied: analytics-python in /usr/local/lib/python3.11/site-packages (from mitoinstaller) (1.4.post1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/site-packages (from mitoinstaller) (0.4.6)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/site-packages (from mitoinstaller) (2.3.0)
# Requirement already satisfied: requests<3.0,>=2.7 in /usr/local/lib/python3.11/site-packages (from analytics-python->mitoinstaller) (2.31.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from analytics-python->mitoinstaller) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/site-packages (from analytics-python->mitoinstaller) (1.6)
# Requirement already satisfied: backoff==1.10.0 in /usr/local/lib/python3.11/site-packages (from analytics-python->mitoinstaller) (1.10.0)
# Requirement already satisfied: python-dateutil>2.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from analytics-python->mitoinstaller) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests<3.0,>=2.7->analytics-python->mitoinstaller) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests<3.0,>=2.7->analytics-python->mitoinstaller) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests<3.0,>=2.7->analytics-python->mitoinstaller) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests<3.0,>=2.7->analytics-python->mitoinstaller) (2023.5.7)
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Requirement already satisfied: joblib~=1.1.0 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (1.11.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (1.5.3)
# Requirement already satisfied: matplotlib>=3.2.0 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (3.7.2)
# Requirement already satisfied: pydantic>=1.8.1 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (2.0.2)
# Requirement already satisfied: PyYAML>=5.0.0 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (2.1.3)
# Collecting visions[type_image_path]==0.7.4 (from pandas-profiling)
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (1.24.2)
# Requirement already satisfied: htmlmin>=0.1.12 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (0.1.12)
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Using cached phik-0.12.3-cp311-cp311-macosx_10_13_x86_64.whl (652 kB)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (4.65.0)
# Collecting seaborn>=0.10.1 (from pandas-profiling)
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: multimethod>=1.4 in /usr/local/lib/python3.11/site-packages (from pandas-profiling) (1.9.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (3.1)
# Requirement already satisfied: imagehash in /usr/local/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2022.7.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (0.5.0)
# Requirement already satisfied: pydantic-core==2.1.2 in /usr/local/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (2.1.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.11/site-packages (from pydantic>=1.8.1->pandas-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.24.0->pandas-profiling) (2023.5.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.11/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.4.1)
# Installing collected packages: visions, seaborn, phik, missingno, pandas-profiling
# Successfully installed missingno-0.5.2 pandas-profiling-3.2.0 phik-0.12.3 seaborn-0.12.2 visions-0.7.4
# Requirement already satisfied: lux-api in /usr/local/lib/python3.11/site-packages (0.5.1)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/lib/python3.11/site-packages (from lux-api) (1.11.1)
# Requirement already satisfied: altair>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lux-api) (5.0.1)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/site-packages (from lux-api) (1.24.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from lux-api) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/site-packages (from lux-api) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.11/site-packages (from lux-api) (3.7.2)
# Requirement already satisfied: lux-widget>=0.1.4 in /usr/local/lib/python3.11/site-packages (from lux-api) (0.1.11)
# Requirement already satisfied: autopep8>=1.5 in /usr/local/lib/python3.11/site-packages (from lux-api) (2.0.2)
# Requirement already satisfied: iso3166 in /usr/local/lib/python3.11/site-packages (from lux-api) (2.1.1)
# Requirement already satisfied: psutil>=5.9.0 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from lux-api) (5.9.4)
# Requirement already satisfied: sh in /usr/local/lib/python3.11/site-packages (from lux-api) (2.0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from altair>=4.0.0->lux-api) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/site-packages (from altair>=4.0.0->lux-api) (4.18.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/site-packages (from altair>=4.0.0->lux-api) (0.12.0)
# Requirement already satisfied: pycodestyle>=2.10.0 in /usr/local/lib/python3.11/site-packages (from autopep8>=1.5->lux-api) (2.10.0)
# Requirement already satisfied: notebook>=4.0.0 in /usr/local/lib/python3.11/site-packages (from lux-widget>=0.1.4->lux-api) (6.5.4)
# Requirement already satisfied: ipywidgets>=7.5.0 in /usr/local/lib/python3.11/site-packages (from lux-widget>=0.1.4->lux-api) (8.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from matplotlib>=3.0.0->lux-api) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from matplotlib>=3.0.0->lux-api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->lux-api) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/site-packages (from scikit-learn>=0.22->lux-api) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/site-packages (from scikit-learn>=0.22->lux-api) (3.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (6.21.1)
# Requirement already satisfied: ipython>=6.1.0 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (8.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /usr/local/lib/python3.11/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /usr/local/lib/python3.11/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.8)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (2023.6.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (0.29.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (0.8.10)
# Requirement already satisfied: tornado>=6.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.2)
# Requirement already satisfied: pyzmq>=17 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (25.0.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (5.2.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (8.0.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (5.9.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (7.6.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->lux-api) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->altair>=4.0.0->lux-api) (2.1.3)
# Requirement already satisfied: appnope in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (1.6.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.6)
# Requirement already satisfied: backcall in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.0)
# Requirement already satisfied: decorator in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.15.1)
# Requirement already satisfied: stack-data in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from jupyter-core>=4.6.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.6.2)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.7.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.11/site-packages (from nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.11/site-packages (from nbformat->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.17.1)
# Requirement already satisfied: ptyprocess in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from terminado>=0.8.3->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/site-packages (from argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.8.3)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.7.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in /usr/local/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /usr/local/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.4.4)
# Requirement already satisfied: overrides in /usr/local/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (7.3.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.6.1)
# Requirement already satisfied: wcwidth in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.6)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (2.4)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.11/site-packages (from isoduration->jsonschema>=3.0->altair>=4.0.0->lux-api) (1.2.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/site-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from plotly) (23.0)
# Collecting bokeh
#   Downloading bokeh-3.2.0-py3-none-any.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 8.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.11/site-packages (from bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.11/site-packages (from bokeh) (1.1.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.11/site-packages (from bokeh) (1.24.2)
# Requirement already satisfied: packaging>=16.8 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from bokeh) (23.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/site-packages (from bokeh) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.11/site-packages (from bokeh) (10.0.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.11/site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from bokeh) (6.2)
# Collecting xyzservices>=2021.09.1 (from bokeh)
#   Downloading xyzservices-2023.5.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/anirudh/Library/Python/3.11/lib/python/site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas>=1.2->bokeh) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas>=1.2->bokeh) (1.16.0)
# Installing collected packages: xyzservices, bokeh
# Successfully installed bokeh-3.2.0 xyzservices-2023.5.0
# Collecting mahotas
#   Downloading mahotas-1.4.13.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from mahotas) (1.24.2)
# Building wheels for collected packages: mahotas
#   Building wheel for mahotas (setup.py) ... done
#   Created wheel for mahotas: filename=mahotas-1.4.13-cp311-cp311-macosx_13_0_x86_64.whl size=1866499 sha256=9b837de23ec012442d7959753ab65dc383ec35eb69ce76d202aaba242b3f6c43
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/b3/2e/49/fbef53473afca72b6ae846774d57f7085df08601d473369b35
# Successfully built mahotas
# Installing collected packages: mahotas
# Successfully installed mahotas-1.4.13
# Collecting simpleitk
#   Downloading SimpleITK-2.2.1-cp311-cp311-macosx_10_9_x86_64.whl (45.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 MB 8.2 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: simpleitk
# Successfully installed simpleitk-2.2.1
# Collecting selenium
#   Downloading selenium-4.10.0-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 11.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.11/site-packages (from selenium) (2.0.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.22.1-py3-none-any.whl (399 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 11.4 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.11/site-packages (from selenium) (2023.5.7)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.11/site-packages (from trio~=0.17->selenium) (23.1.0)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0)
# Collecting exceptiongroup (from trio-websocket~=0.9->selenium)
#   Downloading exceptiongroup-1.1.2-py3-none-any.whl (14 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sortedcontainers, pysocks, outcome, h11, exceptiongroup, wsproto, trio, trio-websocket, selenium
# Successfully installed exceptiongroup-1.1.2 h11-0.14.0 outcome-1.2.0 pysocks-1.7.1 selenium-4.10.0 sortedcontainers-2.4.0 trio-0.22.1 trio-websocket-0.10.3 wsproto-1.2.0
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/site-packages (from beautifulsoup4) (2.4.1)
# Collecting yahoo-finance
#   Using cached yahoo-finance-1.4.0.tar.gz (8.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/site-packages (from yahoo-finance) (2022.7.1)
# Collecting simplejson (from yahoo-finance)
#   Downloading simplejson-3.19.1-cp311-cp311-macosx_10_9_x86_64.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 1.3 MB/s eta 0:00:00ta 0:00:01
# Building wheels for collected packages: yahoo-finance
#   Building wheel for yahoo-finance (setup.py) ... done
#   Created wheel for yahoo-finance: filename=yahoo_finance-1.4.0-py3-none-any.whl size=7216 sha256=0207c69b6ac432e8b286eb4f5208b5fa563e16b4567e608a46458acba81b8f07
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/5a/b7/58/b20d43c1d366893d850dd04003632d56d287b8a91c456662ae
# Successfully built yahoo-finance
# Installing collected packages: simplejson, yahoo-finance
# Successfully installed simplejson-3.19.1 yahoo-finance-1.4.0

# %%
# import turtle library
import turtle             
my_window = turtle.Screen() 
my_window.bgcolor("blue")       # creates a graphics window
my_pen = turtle.Turtle()      
my_pen.forward(150)           
my_pen.left(90)               
my_pen.forward(75)
my_pen.color("white")
my_pen.pensize(12)

# %%
# import turtle library
import turtle             
my_pen = turtle.Turtle()      
for i in range(4):
   my_pen.forward(50)           
   my_pen.right(90)               
turtle.done()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
